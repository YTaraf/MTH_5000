# %% [markdown]
# #MTH 5000 – Applied Forecasting of Financial Data
# ##Lecture 3: Accessing and Retrieving Financial Data
# ##Assignment
# ##**DUE 2/27/26**

# %% [markdown]
# ##Name:

# %% [markdown]
# # **Question 1**:
#
# 1. What stock did you choose? Provide the ticker symbol and full company name.
# 2. Why did you choose this stock? Explain your reasoning, e.g., sector interest, interdependence, personal interest, or availability of data.
# 3. Provide important information about the company:
#    - Sector and industry
#    - Market capitalization (approximate)
#    - Main products or services
#    - Any recent trends or news that may affect its stock performance
#
#
# Write your answers below as Markdown text.

# %% [markdown]
# # **Question 2**:
#
# Each of you is responsible for acquiring, cleaning, and preparing one stock. We will combine them into a unified dataset to study interdependence and forecasting, for now
# 1. Using the yfinance API, pull historical weekly stock data for your chosen stock.
#    - Timeline: 2015–2025
#    - Frequency: Weekly
#    - Features: Price	Close	High	Low	Open	Volume
# 2. Display the first 5 rows of your dataset.

# %% [markdown]
# # **Question 3**:
#
# 1. Check your weekly dataset for any missing dates or gaps.
#    - Hint: Look for missing weeks in the 'Date' column.
# 2. Explain how missing data or outliers could affect analysis with other stocks.
# 3. Suggest a method for handling missing data or outliers if you were to integrate this stock with your peers' datasets.
