# %% [markdown]
# # 🧠 LSTM Stock Forecasting — Starter Notebook
#
# Fill in the TODO sections to complete the assignment.
#
# ---
#
# ## 🎯 Objective
# Build an LSTM model to forecast stock prices using historical data.

# %% [markdown]
# ## 📦 1. Import Libraries (TODO)

# %%
# TODO: Import required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# TODO: Add MinMaxScaler import
# from sklearn.preprocessing import MinMaxScaler

# TODO: Add TensorFlow / Keras imports
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# ## 📂 2. Load Dataset (TODO)

# %%
# TODO: Load dataset

df = pd.read_csv('your_dataset.csv')

# TODO: Convert Date column
# TODO: Sort by Date
# TODO: Set Date as index

df.head()

# %% [markdown]
# ## 📊 3. Feature Selection (TODO)

# %%
# TODO: Define feature list

features = [
    # 'Close', 'High', 'Low', 'Open', 'Volume',
    # 'Return', 'Open_Close_Diff', 'High_Low', 'Abs_Return'
]

data = df[features]

data.head()

# %% [markdown]
# ## 📏 4. Data Scaling (TODO)

# %%
# TODO: Initialize scaler
# scaler = MinMaxScaler()

# TODO: Fit and transform data
# scaled_data = scaler.fit_transform(data)

# %% [markdown]
# ## 🔁 5. Create Sequences (Sliding Window)

# %%
def create_sequences(data, seq_length=60):
    X, y = [], []
    
    # TODO: implement sliding window logic
    
    return np.array(X), np.array(y)

# TODO: Generate X and y
# X, y = create_sequences(scaled_data, 60)

# %% [markdown]
# ## ✂️ 6. Train-Test Split (NO SHUFFLING)

# %%
# TODO: split dataset

# split = int(0.8 * len(X))
# X_train = X[:split]
# X_test = X[split:]
# y_train = y[:split]
# y_test = y[split:]

# %% [markdown]
# ## 🧠 7. Build LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

model = Sequential()

# TODO: Add LSTM layers
# model.add(LSTM(...))
# model.add(Dropout(...))

# TODO: Add Dense layers
# model.add(Dense(...))

# TODO: Compile model
# model.compile(optimizer='adam', loss='mse')

# model.summary()

# %% [markdown]
# ## 🚀 8. Train Model

# %%
# TODO: Train model

# history = model.fit(
#     X_train, y_train,
#     epochs=20,
#     batch_size=32,
#     validation_data=(X_test, y_test)
# )

# %% [markdown]
# ## 📉 9. Loss Curve

# %%
# TODO: Plot loss curves

# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss'], label='val')
# plt.legend()
# plt.show()

# %% [markdown]
# ## 🔮 10. Predictions

# %%
# TODO: Make predictions

# predictions = model.predict(X_test)

# TODO: inverse transform predictions

# %% [markdown]
# ## 📊 11. Evaluation Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# TODO: compute metrics
# mse = ...
# rmse = np.sqrt(mse)
# mae = ...

# print results

# %% [markdown]
# ## 🧠 Final Reflection Questions
#
# - Did your model overfit or underfit?
# - How does performance vary across different stocks?
# - Why is stock prediction inherently difficult?
